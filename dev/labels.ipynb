# %%
import numpy as np

# %%
l = np.load('/home/bam/graspnetAPI/graspnet/grasp_label/001_labels.npz')

# %%
l.files
# Out:
# ['points', 'offsets', 'collision', 'scores']

# %%
l['points'].shape
# Out:
# (2250, 3)
